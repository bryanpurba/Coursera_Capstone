# %% [markdown]
# # Question 3

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/bryanpurba/Coursera_Capstone/master/merged.csv', index_col=0)
df.head(10)
# Out:
#   PostalCode      Borough  ...   Latitude  Longitude
# 0        M1B  Scarborough  ...  43.806686 -79.194353
# 1        M1C  Scarborough  ...  43.784535 -79.160497
# 2        M1E  Scarborough  ...  43.763573 -79.188711
# 3        M1G  Scarborough  ...  43.770992 -79.216917
# 4        M1H  Scarborough  ...  43.773136 -79.239476
# 5        M1J  Scarborough  ...  43.744734 -79.239476
# 6        M1K  Scarborough  ...  43.727929 -79.262029
# 7        M1L  Scarborough  ...  43.711112 -79.284577
# 8        M1M  Scarborough  ...  43.716316 -79.239476
# 9        M1N  Scarborough  ...  43.692657 -79.264848
#
# [10 rows x 5 columns]

# %%
from geopy.geocoders import Nominatim

address = 'Toronto, Canada'

geolocator = Nominatim(user_agent="can_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.6534817 -79.3839347

# %%
import folium

map = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map)  
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(df['Borough'].unique()),
        df.shape[0]
    ))
print("The boroughs are: \n {} \n", df['Borough'].unique())
# Out:
# The dataframe has 10 boroughs and 103 neighborhoods.
# The boroughs are:
#  {}
#  ['Scarborough' 'North York' 'East York' 'East Toronto' 'Central Toronto'
#  'Downtown Toronto' 'York' 'West Toronto' 'Mississauga' 'Etobicoke']

# %% [markdown]
# For this problem i am going simplyfy the dataset and focus to Scarborough of toronto. I am going to use K-Clustering to findout the most common venues.

# %%
df_scarborough = df[df['Borough'] == 'Scarborough'].reset_index(drop=True)
df_scarborough.head()

print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(df_scarborough['Borough'].unique()),
        df_scarborough.shape[0]
    ))
# Out:
# The dataframe has 1 boroughs and 17 neighborhoods.

# %% [markdown]
# Let's get the geographical coordinates of Scarborough

# %%
address = 'Scarborough, Toronto'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Scarborough are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Scarborough are 43.773077, -79.257774.

# %% [markdown]
# Visualize the map of Scarborough

# %%
# create map of Manhattan using latitude and longitude values
map_scarborough = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(df_scarborough['Latitude'], df_scarborough['Longitude'], df_scarborough['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_scarborough)  
    
map_scarborough
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Defining Foursquare API and Credentials

# %%
import requests # library to handle requests

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

CLIENT_ID = 'PARHPFYPBADPKA43AY2YGQN5L5GBMYQDY2YIWFB0AUTRS3SP' # your Foursquare ID

CLIENT_SECRET = 'B4ZL1LN2V13SMT4BK4VVGAXPXRBPD31TT0UHGS1KFWO0GHDT' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
radius = 1000
LIMIT = 100

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)

url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
# Out:
# Your credentails:
# CLIENT_ID: PARHPFYPBADPKA43AY2YGQN5L5GBMYQDY2YIWFB0AUTRS3SP
# CLIENT_SECRET:B4ZL1LN2V13SMT4BK4VVGAXPXRBPD31TT0UHGS1KFWO0GHDT

# %% [markdown]
# ## Explore Neighborhoods in Scarborough from Scarborough dataframe

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# type your answer here

scarborough_venues = getNearbyVenues(names=df_scarborough['Neighborhood'],
                                   latitudes=df_scarborough['Latitude'],
                                   longitudes=df_scarborough['Longitude']
                                  )
# Out:
# Malvern, Rouge
# Rouge Hill, Port Union, Highland Creek
# Guildwood, Morningside, West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# Kennedy Park, Ionview, East Birchmount Park
# Golden Mile, Clairlea, Oakridge
# Cliffside, Cliffcrest, Scarborough Village West
# Birch Cliff, Cliffside West
# Dorset Park, Wexford Heights, Scarborough Town Centre
# Wexford, Maryvale
# Agincourt
# Clarks Corners, Tam O'Shanter, Sullivan
# Milliken, Agincourt North, Steeles East, L'Amoreaux East
# Steeles West, L'Amoreaux West
# Upper Rouge

# %% [markdown]
# ## Check how many venues were returned for each neighborhood

# %%
scarborough_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  ...  Venue Category
# Neighborhood                                                               ...
# Agincourt                                                               5  ...               5
# Birch Cliff, Cliffside West                                             4  ...               4
# Cedarbrae                                                               8  ...               8
# Clarks Corners, Tam O'Shanter, Sullivan                                12  ...              12
# Cliffside, Cliffcrest, Scarborough Village West                         2  ...               2
# Dorset Park, Wexford Heights, Scarborough Town ...                      5  ...               5
# Golden Mile, Clairlea, Oakridge                                        10  ...              10
# Guildwood, Morningside, West Hill                                       8  ...               8
# Kennedy Park, Ionview, East Birchmount Park                             4  ...               4
# Malvern, Rouge                                                          1  ...               1
# Milliken, Agincourt North, Steeles East, L'Amor...                      3  ...               3
# Rouge Hill, Port Union, Highland Creek                                  2  ...               2
# Scarborough Village                                                     3  ...               3
# Steeles West, L'Amoreaux West                                          12  ...              12
# Wexford, Maryvale                                                       6  ...               6
# Woburn                                                                  4  ...               4
#
# [16 rows x 6 columns]

# %%
print('There are {} uniques categories.'.format(len(scarborough_venues['Venue Category'].unique())))
# Out:
# There are 55 uniques categories.

# %% [markdown]
# ## Analyze each Neighborhoods

# %%
# one hot encoding
scarborough_onehot = pd.get_dummies(scarborough_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
scarborough_onehot['Neighborhood'] = scarborough_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [scarborough_onehot.columns[-1]] + list(scarborough_onehot.columns[:-1])
scarborough_onehot = scarborough_onehot[fixed_columns]

scarborough_onehot.head()
# Out:
#                              Neighborhood  ...  Vietnamese Restaurant
# 0                          Malvern, Rouge  ...                      0
# 1  Rouge Hill, Port Union, Highland Creek  ...                      0
# 2  Rouge Hill, Port Union, Highland Creek  ...                      0
# 3       Guildwood, Morningside, West Hill  ...                      0
# 4       Guildwood, Morningside, West Hill  ...                      0
#
# [5 rows x 56 columns]

# %%
scarborough_onehot.shape
# Out:
# (89, 56)

# %% [markdown]
# #### Next, let's group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
scarborough_grouped = scarborough_onehot.groupby('Neighborhood').mean().reset_index()
scarborough_grouped
# Out:
#                                          Neighborhood  ...  Vietnamese Restaurant
# 0                                           Agincourt  ...                    0.0
# 1                         Birch Cliff, Cliffside West  ...                    0.0
# 2                                           Cedarbrae  ...                    0.0
# 3             Clarks Corners, Tam O'Shanter, Sullivan  ...                    0.0
# 4     Cliffside, Cliffcrest, Scarborough Village West  ...                    0.0
# 5   Dorset Park, Wexford Heights, Scarborough Town...  ...                    0.2
# 6                     Golden Mile, Clairlea, Oakridge  ...                    0.0
# 7                   Guildwood, Morningside, West Hill  ...                    0.0
# 8         Kennedy Park, Ionview, East Birchmount Park  ...                    0.0
# 9                                      Malvern, Rouge  ...                    0.0
# 10  Milliken, Agincourt North, Steeles East, L'Amo...  ...                    0.0
# 11             Rouge Hill, Port Union, Highland Creek  ...                    0.0
# 12                                Scarborough Village  ...                    0.0
# 13                      Steeles West, L'Amoreaux West  ...                    0.0
# 14                                  Wexford, Maryvale  ...                    0.0
# 15                                             Woburn  ...                    0.0
#
# [16 rows x 56 columns]

# %% [markdown]
# #### Let's confirm the new size

# %%
scarborough_grouped.shape
# Out:
# (16, 56)

# %% [markdown]
# #### Let's print each neighborhood along with the top 10 most common venues

# %%
num_top_venues = 10

for hood in scarborough_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = scarborough_grouped[scarborough_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Agincourt----
#                        venue  freq
# 0  Latin American Restaurant   0.2
# 1                     Lounge   0.2
# 2               Skating Rink   0.2
# 3             Breakfast Spot   0.2
# 4             Clothing Store   0.2
# 5          Accessories Store   0.0
# 6                       Park   0.0
# 7              Jewelry Store   0.0
# 8          Korean Restaurant   0.0
# 9             Medical Center   0.0
#
#
# ----Birch Cliff, Cliffside West----
#                        venue  freq
# 0               Skating Rink  0.25
# 1      General Entertainment  0.25
# 2                       Café  0.25
# 3            College Stadium  0.25
# 4          Accessories Store  0.00
# 5                       Park  0.00
# 6              Jewelry Store  0.00
# 7          Korean Restaurant  0.00
# 8  Latin American Restaurant  0.00
# 9                     Lounge  0.00
#
#
# ----Cedarbrae----
#                   venue  freq
# 0    Athletics & Sports  0.12
# 1   Fried Chicken Joint  0.12
# 2                Bakery  0.12
# 3                  Bank  0.12
# 4       Thai Restaurant  0.12
# 5           Gas Station  0.12
# 6      Hakka Restaurant  0.12
# 7  Caribbean Restaurant  0.12
# 8     Accessories Store  0.00
# 9    Mexican Restaurant  0.00
#
#
# ----Clarks Corners, Tam O'Shanter, Sullivan----
#                   venue  freq
# 0           Pizza Place  0.17
# 1    Italian Restaurant  0.08
# 2  Fast Food Restaurant  0.08
# 3   Fried Chicken Joint  0.08
# 4           Gas Station  0.08
# 5              Pharmacy  0.08
# 6    Chinese Restaurant  0.08
# 7          Noodle House  0.08
# 8                  Bank  0.08
# 9       Thai Restaurant  0.08
#
#
# ----Cliffside, Cliffcrest, Scarborough Village West----
#                        venue  freq
# 0        American Restaurant   0.5
# 1                      Motel   0.5
# 2          Indian Restaurant   0.0
# 3               Intersection   0.0
# 4         Italian Restaurant   0.0
# 5              Jewelry Store   0.0
# 6          Korean Restaurant   0.0
# 7  Latin American Restaurant   0.0
# 8                     Lounge   0.0
# 9             Medical Center   0.0
#
#
# ----Dorset Park, Wexford Heights, Scarborough Town Centre----
#                        venue  freq
# 0          Indian Restaurant   0.4
# 1      Vietnamese Restaurant   0.2
# 2         Chinese Restaurant   0.2
# 3                  Pet Store   0.2
# 4               Soccer Field   0.0
# 5                 Smoke Shop   0.0
# 6         Italian Restaurant   0.0
# 7              Jewelry Store   0.0
# 8          Korean Restaurant   0.0
# 9  Latin American Restaurant   0.0
#
#
# ----Golden Mile, Clairlea, Oakridge----
#                        venue  freq
# 0                   Bus Line   0.2
# 1                     Bakery   0.2
# 2                       Park   0.1
# 3               Intersection   0.1
# 4              Metro Station   0.1
# 5                Bus Station   0.1
# 6             Ice Cream Shop   0.1
# 7               Soccer Field   0.1
# 8                     Lounge   0.0
# 9  Latin American Restaurant   0.0
#
#
# ----Guildwood, Morningside, West Hill----
#                  venue  freq
# 0       Medical Center  0.12
# 1       Breakfast Spot  0.12
# 2         Intersection  0.12
# 3   Mexican Restaurant  0.12
# 4  Rental Car Location  0.12
# 5           Restaurant  0.12
# 6    Electronics Store  0.12
# 7                 Bank  0.12
# 8               Lounge  0.00
# 9         Noodle House  0.00
#
#
# ----Kennedy Park, Ionview, East Birchmount Park----
#                        venue  freq
# 0                Coffee Shop  0.25
# 1              Train Station  0.25
# 2                 Hobby Shop  0.25
# 3           Department Store  0.25
# 4                       Park  0.00
# 5              Jewelry Store  0.00
# 6          Korean Restaurant  0.00
# 7  Latin American Restaurant  0.00
# 8                     Lounge  0.00
# 9             Medical Center  0.00
#
#
# ----Malvern, Rouge----
#                        venue  freq
# 0       Fast Food Restaurant   1.0
# 1          Accessories Store   0.0
# 2          Indian Restaurant   0.0
# 3         Italian Restaurant   0.0
# 4              Jewelry Store   0.0
# 5          Korean Restaurant   0.0
# 6  Latin American Restaurant   0.0
# 7                     Lounge   0.0
# 8             Medical Center   0.0
# 9              Metro Station   0.0
#
#
# ----Milliken, Agincourt North, Steeles East, L'Amoreaux East----
#                        venue  freq
# 0                       Park  0.33
# 1                     Bakery  0.33
# 2                 Playground  0.33
# 3          Accessories Store  0.00
# 4         Italian Restaurant  0.00
# 5              Jewelry Store  0.00
# 6          Korean Restaurant  0.00
# 7  Latin American Restaurant  0.00
# 8                     Lounge  0.00
# 9             Medical Center  0.00
#
#
# ----Rouge Hill, Port Union, Highland Creek----
#                         venue  freq
# 0                         Bar   0.5
# 1  Construction & Landscaping   0.5
# 2           Accessories Store   0.0
# 3                        Park   0.0
# 4               Jewelry Store   0.0
# 5           Korean Restaurant   0.0
# 6   Latin American Restaurant   0.0
# 7                      Lounge   0.0
# 8              Medical Center   0.0
# 9               Metro Station   0.0
#
#
# ----Scarborough Village----
#                        venue  freq
# 0              Jewelry Store  0.33
# 1                 Smoke Shop  0.33
# 2                 Playground  0.33
# 3          Accessories Store  0.00
# 4               Noodle House  0.00
# 5         Italian Restaurant  0.00
# 6          Korean Restaurant  0.00
# 7  Latin American Restaurant  0.00
# 8                     Lounge  0.00
# 9             Medical Center  0.00
#
#
# ----Steeles West, L'Amoreaux West----
#                   venue  freq
# 0  Fast Food Restaurant  0.17
# 1           Pizza Place  0.08
# 2              Pharmacy  0.08
# 3           Coffee Shop  0.08
# 4    Chinese Restaurant  0.08
# 5         Grocery Store  0.08
# 6                   Gym  0.08
# 7        Sandwich Place  0.08
# 8        Breakfast Spot  0.08
# 9                  Bank  0.08
#
#
# ----Wexford, Maryvale----
#                        venue  freq
# 0          Accessories Store  0.17
# 1                Auto Garage  0.17
# 2                     Bakery  0.17
# 3                 Smoke Shop  0.17
# 4             Sandwich Place  0.17
# 5  Middle Eastern Restaurant  0.17
# 6                       Park  0.00
# 7              Jewelry Store  0.00
# 8          Korean Restaurant  0.00
# 9  Latin American Restaurant  0.00
#
#
# ----Woburn----
#                        venue  freq
# 0                Coffee Shop  0.50
# 1          Korean Restaurant  0.25
# 2         Mexican Restaurant  0.25
# 3          Indian Restaurant  0.00
# 4         Italian Restaurant  0.00
# 5              Jewelry Store  0.00
# 6  Latin American Restaurant  0.00
# 7                     Lounge  0.00
# 8             Medical Center  0.00
# 9              Metro Station  0.00

# %% [markdown]
# #### Let's put that into a *pandas* dataframe

# %% [markdown]
# First, let's write a function to sort the venues in descending order.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Now let's create the new dataframe and display the top 10 venues for each neighborhood.

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = scarborough_grouped['Neighborhood']

for ind in np.arange(scarborough_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(scarborough_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#                                          Neighborhood  ...      10th Most Common Venue
# 0                                           Agincourt  ...                 Gas Station
# 1                         Birch Cliff, Cliffside West  ...         Fried Chicken Joint
# 2                                           Cedarbrae  ...                         Gym
# 3             Clarks Corners, Tam O'Shanter, Sullivan  ...          Italian Restaurant
# 4     Cliffside, Cliffcrest, Scarborough Village West  ...           Electronics Store
# 5   Dorset Park, Wexford Heights, Scarborough Town...  ...                 Gas Station
# 6                     Golden Mile, Clairlea, Oakridge  ...                 Coffee Shop
# 7                   Guildwood, Morningside, West Hill  ...  Construction & Landscaping
# 8         Kennedy Park, Ionview, East Birchmount Park  ...         Fried Chicken Joint
# 9                                      Malvern, Rouge  ...            Department Store
# 10  Milliken, Agincourt North, Steeles East, L'Amo...  ...        Fast Food Restaurant
# 11             Rouge Hill, Port Union, Highland Creek  ...        Fast Food Restaurant
# 12                                Scarborough Village  ...        Fast Food Restaurant
# 13                      Steeles West, L'Amoreaux West  ...              Sandwich Place
# 14                                  Wexford, Maryvale  ...         Fried Chicken Joint
# 15                                             Woburn  ...        Fast Food Restaurant
#
# [16 rows x 11 columns]

# %% [markdown]
# <a id='item4'></a>

# %% [markdown]
# ## Cluster the Neighborhoods and findout most common venues in neighborhoods
#
# Using K-Cluester with K = 5

# %%
from sklearn.cluster import KMeans

# set number of clusters
kclusters = 5

scarborough_grouped_clustering = scarborough_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(scarborough_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 1, 1, 1, 0, 1, 1, 1, 3, 4], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

scarborough_merged = df_scarborough


# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
scarborough_merged = scarborough_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

scarborough_merged.head() # check the last columns!
# Out:
#   PostalCode      Borough  ... 9th Most Common Venue      10th Most Common Venue
# 0        M1B  Scarborough  ...     Electronics Store            Department Store
# 1        M1C  Scarborough  ...   Fried Chicken Joint        Fast Food Restaurant
# 2        M1E  Scarborough  ...       College Stadium  Construction & Landscaping
# 3        M1G  Scarborough  ...   Fried Chicken Joint        Fast Food Restaurant
# 4        M1H  Scarborough  ...       College Stadium                         Gym
#
# [5 rows x 16 columns]

# %%
# scarborough_merged = scarborough_merged.dropna
# scarborough_merged.isnull().values.any()
scarborough_merged = scarborough_merged.dropna()

# %%
# create map
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(scarborough_merged['Latitude'], scarborough_merged['Longitude'], scarborough_merged['Neighborhood'], scarborough_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster-1)],
        fill=True,
        fill_color=rainbow[int(cluster-1)],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 5. Examine Clusters

# %% [markdown]
# Now, you can examine each cluster and determine the discriminating venue categories that distinguish each cluster. Based on the defining categories, you can then assign a name to each cluster. I will leave this exercise to you.

# %% [markdown]
# #### Cluster 1

# %%
scarborough_merged.loc[scarborough_merged['Cluster Labels'] == 0, scarborough_merged.columns[[1] + list(range(5, scarborough_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 8  Scarborough             0.0  ...  Fast Food Restaurant      Electronics Store
#
# [1 rows x 12 columns]

# %% [markdown]
# #### Cluster 2

# %%
scarborough_merged.loc[scarborough_merged['Cluster Labels'] == 1, scarborough_merged.columns[[1] + list(range(5, scarborough_merged.shape[1]))]]
# Out:
#         Borough  ...      10th Most Common Venue
# 2   Scarborough  ...  Construction & Landscaping
# 4   Scarborough  ...                         Gym
# 5   Scarborough  ...        Fast Food Restaurant
# 7   Scarborough  ...                 Coffee Shop
# 9   Scarborough  ...         Fried Chicken Joint
# 10  Scarborough  ...                 Gas Station
# 11  Scarborough  ...         Fried Chicken Joint
# 12  Scarborough  ...                 Gas Station
# 13  Scarborough  ...          Italian Restaurant
# 14  Scarborough  ...        Fast Food Restaurant
# 15  Scarborough  ...              Sandwich Place
#
# [11 rows x 12 columns]

# %% [markdown]
# #### Cluster 3

# %%
scarborough_merged.loc[scarborough_merged['Cluster Labels'] == 2, scarborough_merged.columns[[1] + list(range(5, scarborough_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 1  Scarborough             2.0  ...   Fried Chicken Joint   Fast Food Restaurant
#
# [1 rows x 12 columns]

# %% [markdown]
# #### Cluster 4

# %%
scarborough_merged.loc[scarborough_merged['Cluster Labels'] == 3, scarborough_merged.columns[[1] + list(range(5, scarborough_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 3  Scarborough             3.0  ...   Fried Chicken Joint   Fast Food Restaurant
# 6  Scarborough             3.0  ...           Gas Station    Fried Chicken Joint
#
# [2 rows x 12 columns]

# %% [markdown]
# #### Cluster 5

# %%
scarborough_merged.loc[scarborough_merged['Cluster Labels'] == 4, scarborough_merged.columns[[1] + list(range(5, scarborough_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 0  Scarborough             4.0  ...     Electronics Store       Department Store
#
# [1 rows x 12 columns]

# %%
# !bash
# Out:
# bash: cannot set terminal process group (787): Inappropriate ioctl for device
# bash: no job control in this shell
# root@931bb7f0d3ef:/content#
# root@931bb7f0d3ef:/content#
# root@931bb7f0d3ef:/content# ls
# sample_data
# root@931bb7f0d3ef:/content# exit
# exit
